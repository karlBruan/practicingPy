# %% [markdown]
# <a href="https://colab.research.google.com/github/karlBruan/practicingPy/blob/main/Conditionals%2C_For_and_While_loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Conditionals and Loops**

# %% [markdown]
# ## **'IF' Statement**
#
# ![flowchart_if_only.png](data:image/png;base64,...)

# %%
food = 'spam'

if food == 'spam':
    print('Ummmm, my favorite!')
    print('I feel like saying it 100 times...')
    print(100 * (food + '! '))

# %% [markdown]
# ## **'IF-ELSE' Stament**
#
# ![flowchart_if_else.png](data:image/png;base64,...)

# %%
food = 'spam'

if food == 'spam':
    print('Ummmm, my favorite!')
else:
    print("No, I won't have it. I want spam!")

# %% [markdown]
# ## **Chained Conditionals**
#
# ![flowchart_chained_conditional.png](data:image/png;base64,...)

# %%
choice = 'a'

if choice == 'a':
    print("You chose 'a'.")
elif choice == 'b':
    print("You chose 'b'.")
elif choice == 'c':
    print("You chose 'c'.")
else:
    print("Invalid choice.")

# %% [markdown]
# ## **Nested Conditionals**
#
# ![flowchart_nested_conditional.png](data:image/png;base64,...)

# %%
x = 100
cuss = 'fuck outta here'
if 0 < x:            # assume x is an int here
    if x < 10:
        print("x is a positive single digit.")
    elif x > 10 and x < 100:
      print("x is a positive double digit.")
    else:
      print(cuss)
# Out:
# fuck outta here

# %% [markdown]
# ## **FOR Loop**
#
# ![python-for-loop.png](data:image/png;base64,...)

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x, '\n')

for friend in ['Margot', 'Kathryn', 'Prisila']:
    invitation = "Hi " + friend + ".  Please come to my party on Saturday!"
    print(invitation)

for i in range(20):
  print("number:",i, end = "\n")
# Out:
# apple
#
# banana
#
# cherry
#
# Hi Margot.  Please come to my party on Saturday!
# Hi Kathryn.  Please come to my party on Saturday!
# Hi Prisila.  Please come to my party on Saturday!
# number: 0
# number: 1
# number: 2
# number: 3
# number: 4
# number: 5
# number: 6
# number: 7
# number: 8
# number: 9
# number: 10
# number: 11
# number: 12
# number: 13
# number: 14
# number: 15
# number: 16
# number: 17
# number: 18
# number: 19

# %%
##Nested Loops and Nested Data

students = [("Alejandro", ["CompSci", "Physics"]),
            ("Justin", ["Math", "CompSci", "Stats"]),
            ("Ed", ["CompSci", "Accounting", "Economics"]),
            ("Margot", ["InfSys", "Accounting", "Economics", "CommLaw"]),
            ("Peter", ["Sociology", "Economics", "Law", "Stats", "Music"])]

# print all students with a count of their courses.
for (name, subjects) in students:
    print(name, "takes", len(subjects), "courses")


# Count how many students are taking CompSci
counter = 0
for (name, subjects) in students:
    for s in subjects:                 # a nested loop!
        if s == "CompSci":
            counter += 1

print("\n\nThe number of students taking CompSci is", counter)
# Out:
# Alejandro takes 2 courses
# Justin takes 3 courses
# Ed takes 3 courses
# Margot takes 4 courses
# Peter takes 5 courses
#
#
# The number of students taking CompSci is 3

# %% [markdown]
# ## **WHILE Loop**
#
# ![while_loop_C.jpeg](data:image/jpeg;base64,...)

# %%
number = 0
prompt = "What is the meaning of life, the universe, and everything? "

while number != "42":
    number =  input(prompt)
# Out:
# What is the meaning of life, the universe, and everything? 78
# What is the meaning of life, the universe, and everything? 48
# What is the meaning of life, the universe, and everything? 42

# %%
name = 'Harrison'
guess = input("So I'm thinking of person's name. Try to guess it: ")
pos = 0

while guess != name and pos < len(name):
    print("Nope, that's not it! Hint: letter ", end='')
    print(pos + 1, "is", name[pos] + ". ", end='')
    guess = input("Guess again: ")
    pos = pos + 1

if pos == len(name) and name != guess:
    print("Too bad, you couldn't get it.  The name was", name + ".")
else:
    print("\nGreat, you got it in", pos + 1,  "guesses!")
# Out:
# So I'm thinking of person's name. Try to guess it: leane
# Nope, that's not it! Hint: letter 1 is H. Guess again: Harrison
#
# Great, you got it in 2 guesses!
